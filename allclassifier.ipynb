# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# Load the datasets
features_df = pd.read_csv("data/training_set_features.csv", index_col="respondent_id")
labels_df = pd.read_csv("data/training_set_labels.csv", index_col="respondent_id")

# Verify the loaded data
print("Features DataFrame:")
print(features_df.head())
print("\nLabels DataFrame:")
print(labels_df.head())

# Features and targets
features = features_df
target_h1n1 = labels_df['h1n1_vaccine']
target_seasonal = labels_df['seasonal_vaccine']

# Split the data for h1n1_vaccine
X_train_h1n1, X_test_h1n1, y_train_h1n1, y_test_h1n1 = train_test_split(features, target_h1n1, test_size=0.2, random_state=42)

# Initialize LazyClassifier for h1n1_vaccine
clf_h1n1 = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_h1n1, predictions_h1n1 = clf_h1n1.fit(X_train_h1n1, X_test_h1n1, y_train_h1n1, y_test_h1n1)

print("H1N1 Vaccine Models:")
print(models_h1n1)

# Split the data for seasonal_vaccine
X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal = train_test_split(features, target_seasonal, test_size=0.2, random_state=42)

# Initialize LazyClassifier for seasonal_vaccine
clf_seasonal = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_seasonal, predictions_seasonal = clf_seasonal.fit(X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal)

print("Seasonal Vaccine Models:")
print(models_seasonal)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features DataFrame:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 0                      1.00            0.00                       0.00
# 1                      3.00            2.00                       0.00
# 2                      1.00            1.00                       0.00
# 3                      1.00            1.00                       0.00
# 4                      2.00            1.00                       0.00
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 0                              0.00                  0.00
# 1                              1.00                  0.00
# 2                              1.00                  0.00
# 3                              1.00                  0.00
# 4                              1.00                  0.00
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 0                               0.00                         0.00
# 1                               1.00                         0.00
# 2                               0.00                         0.00
# 3                               1.00                         1.00
# 4                               1.00                         1.00
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 0                                 1.00                   1.00
# 1                                 1.00                   1.00
# 2                                 0.00                   0.00
# 3                                 0.00                   0.00
# 4                                 0.00                   1.00
#
#                doctor_recc_h1n1  ...             income_poverty  \
# respondent_id                    ...
# 0                          0.00  ...              Below Poverty
# 1                          0.00  ...              Below Poverty
# 2                           nan  ...  <= $75,000, Above Poverty
# 3                          0.00  ...              Below Poverty
# 4                          0.00  ...  <= $75,000, Above Poverty
#
#                marital_status  rent_or_own   employment_status  \
# respondent_id
# 0                 Not Married          Own  Not in Labor Force
# 1                 Not Married         Rent            Employed
# 2                 Not Married          Own            Employed
# 3                 Not Married         Rent  Not in Labor Force
# 4                     Married          Own            Employed
#
#                hhs_geo_region                census_msa  household_adults  \
# respondent_id
# 0                    oxchjgsf                   Non-MSA              0.00
# 1                    bhuqouqj  MSA, Not Principle  City              0.00
# 2                    qufhixun  MSA, Not Principle  City              2.00
# 3                    lrircsnp       MSA, Principle City              0.00
# 4                    qufhixun  MSA, Not Principle  City              1.00
#
#                household_children  employment_industry  employment_occupation
# respondent_id
# 0                            0.00                  NaN                    NaN
# 1                            0.00             pxcmvdjn               xgwztkwe
# 2                            0.00             rucpziij               xtkaffoo
# 3                            0.00                  NaN                    NaN
# 4                            0.00             wxleyezf               emcorrxb
#
# [5 rows x 35 columns]
#
# Labels DataFrame:
#                h1n1_vaccine  seasonal_vaccine
# respondent_id
# 0                         0                 0
# 1                         0                 1
# 2                         0                 0
# 3                         0                 1
# 4                         0                 0
# 100%|██████████| 29/29 [02:53<00:00,  5.97s/it]
#   0%|          | 0/29 [00:00<?, ?it/s]
# H1N1 Vaccine Models:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.86               0.73     0.73      0.85
# XGBClassifier                      0.85               0.73     0.73      0.84
# AdaBoostClassifier                 0.85               0.72     0.72      0.84
# GaussianNB                         0.75               0.71     0.71      0.77
# BernoulliNB                        0.80               0.71     0.71      0.80
# LinearDiscriminantAnalysis         0.84               0.70     0.70      0.82
# BaggingClassifier                  0.84               0.70     0.70      0.83
# RandomForestClassifier             0.85               0.69     0.69      0.83
# CalibratedClassifierCV             0.84               0.69     0.69      0.82
# ExtraTreesClassifier               0.85               0.68     0.68      0.83
# RidgeClassifier                    0.84               0.67     0.67      0.82
# RidgeClassifierCV                  0.84               0.67     0.67      0.82
# LinearSVC                          0.84               0.67     0.67      0.82
# DecisionTreeClassifier             0.77               0.67     0.67      0.77
# SVC                                0.83               0.67     0.67      0.81
# NearestCentroid                    0.65               0.66     0.66      0.68
# ExtraTreeClassifier                0.76               0.65     0.65      0.76
# QuadraticDiscriminantAnalysis      0.66               0.65     0.65      0.69
# KNeighborsClassifier               0.81               0.65     0.65      0.79
# Perceptron                         0.47               0.63     0.63      0.49
# LabelSpreading                     0.76               0.62     0.62      0.76
# LabelPropagation                   0.76               0.62     0.62      0.76
# PassiveAggressiveClassifier        0.36               0.57     0.57      0.34
# SGDClassifier                      0.81               0.56     0.56      0.75
# DummyClassifier                    0.67               0.50     0.50      0.67
#
#                                Time Taken
# Model
# LGBMClassifier                      51.88
# XGBClassifier                       39.58
# AdaBoostClassifier                   0.99
# GaussianNB                           0.12
# BernoulliNB                          0.12
# LinearDiscriminantAnalysis           0.30
# BaggingClassifier                    1.05
# RandomForestClassifier               1.82
# CalibratedClassifierCV               9.14
# ExtraTreesClassifier                 2.35
# RidgeClassifier                      0.13
# RidgeClassifierCV                    0.23
# LinearSVC                            2.80
# DecisionTreeClassifier               0.23
# SVC                                 17.54
# NearestCentroid                      0.21
# ExtraTreeClassifier                  0.11
# QuadraticDiscriminantAnalysis        0.26
# KNeighborsClassifier                 4.18
# Perceptron                           0.19
# LabelSpreading                      25.23
# LabelPropagation                    13.03
# PassiveAggressiveClassifier          0.19
# SGDClassifier                        0.56
# DummyClassifier                      0.09
# 100%|██████████| 29/29 [03:35<00:00,  7.44s/it]
# Seasonal Vaccine Models:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.79               0.79     0.79      0.79
# SVC                                0.79               0.79     0.79      0.79
# AdaBoostClassifier                 0.79               0.78     0.78      0.79
# NuSVC                              0.78               0.78     0.78      0.78
# RandomForestClassifier             0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# LinearDiscriminantAnalysis         0.78               0.78     0.78      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# CalibratedClassifierCV             0.78               0.78     0.78      0.78
# ExtraTreesClassifier               0.78               0.78     0.78      0.78
# XGBClassifier                      0.78               0.78     0.78      0.78
# LinearSVC                          0.77               0.76     0.76      0.77
# BernoulliNB                        0.76               0.76     0.76      0.76
# BaggingClassifier                  0.76               0.75     0.75      0.75
# PassiveAggressiveClassifier        0.74               0.74     0.74      0.74
# GaussianNB                         0.72               0.72     0.72      0.72
# KNeighborsClassifier               0.72               0.72     0.72      0.72
# SGDClassifier                      0.67               0.69     0.69      0.66
# DecisionTreeClassifier             0.69               0.69     0.69      0.69
# QuadraticDiscriminantAnalysis      0.68               0.68     0.68      0.68
# NearestCentroid                    0.66               0.66     0.66      0.65
# ExtraTreeClassifier                0.66               0.65     0.65      0.66
# LabelPropagation                   0.65               0.65     0.65      0.65
# LabelSpreading                     0.65               0.65     0.65      0.65
# Perceptron                         0.62               0.59     0.59      0.55
# DummyClassifier                    0.50               0.50     0.50      0.50
#
#                                Time Taken
# Model
# LGBMClassifier                      58.06
# SVC                                 27.02
# AdaBoostClassifier                   1.02
# NuSVC                               42.84
# RandomForestClassifier               1.86
# RidgeClassifierCV                    0.23
# LinearDiscriminantAnalysis           0.27
# RidgeClassifier                      0.13
# CalibratedClassifierCV               9.14
# ExtraTreesClassifier                 2.41
# XGBClassifier                       27.30
# LinearSVC                            3.39
# BernoulliNB                          0.13
# BaggingClassifier                    1.10
# PassiveAggressiveClassifier          0.15
# GaussianNB                           0.11
# KNeighborsClassifier                 3.78
# SGDClassifier                        0.44
# DecisionTreeClassifier               0.27
# QuadraticDiscriminantAnalysis        0.20
# NearestCentroid                      0.21
# ExtraTreeClassifier                  0.12
# LabelPropagation                    13.47
# LabelSpreading                      20.65
# Perceptron                           0.20
# DummyClassifier                      0.10
